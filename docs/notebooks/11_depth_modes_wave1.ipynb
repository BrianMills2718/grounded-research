# %% [markdown]
# # Depth Modes Wave 1\n\n**Purpose:** Execute the next benchmark-driven depth continuation wave.\n**Status:** in progress\n**Execution mode:** repo-local implementation wave\n\n## Scope\n- depth-aware goal-driven evidence extraction\n- depth-aware multi-round arbitration\n- benchmark/docs gate\n\n## Explicit non-scope\n- full provider-parity work\n- Gemini structured-output evaluation\n- sectioned synthesis unless this wave proves it is necessary\n

# %% [markdown]
# ## Contracts\n\n1. `standard` depth remains the cheap baseline.\n2. `deep` and `thorough` may produce richer per-page evidence from the same fetched source set.\n3. Evidence still lands as ordinary `EvidenceItem`s.\n4. Arbitration looping is controlled only by depth profile and verdict state.\n5. Docs update only after the benchmark gate is run.\n

# %% [markdown]
# ## Acceptance\n\n- targeted collection/verification tests pass\n- `standard` behavior is unchanged\n- `deep`/`thorough` can gather richer evidence from a page and use >1 arbitration round when still inconclusive\n- one benchmark or fixture gate is recorded and the plan status is updated to match it\n
