# %% [markdown]
# # Tyler Remediation Phase 6: Stage 5 Query Roles And Search Controls
#
# ## Goal
#
# Fix the live Stage 5 path so it actually matches Tyler's query-role and search-parameter requirements.
#
# ## Inputs
#
# - `docs/TYLER_SPEC_GAP_LEDGER.md`
# - `src/grounded_research/verify.py`
# - `tests/test_verify.py`
#
# ## Success Criteria
#
# 1. Stage 5 emits neutral, weaker-position, authoritative, and optional dated queries.
# 2. Stage 5 passes advanced/chunks/detail-budget/domain-filter controls through shared search.
# 3. Ledger rows `S5-QUERY-ROLES-001` and `S5-SEARCH-PARAMS-001` move to `verified_fixed` with test evidence.
