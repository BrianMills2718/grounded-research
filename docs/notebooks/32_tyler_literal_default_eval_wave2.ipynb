# %% [markdown]
# # Tyler Literal Default Eval Wave 2
#
# Goal: expand frozen Tyler-vs-legacy evidence beyond the single UBI case.
#
# Chosen case:
# - archived legacy artifact: `output/pfas_v2_analytical/`
# - fixture source: `output/pfas_v2_analytical/collected_bundle.json`
# - new Tyler-literal output: dedicated wave output dir on current `main`
#
# Contracts:
# - legacy side stays frozen and untouched
# - Tyler side is regenerated from the saved PFAS fixture only
# - frozen comparison still runs through `scripts/eval_tyler_variants.py`
# - final claim is limited to two-case directional evidence, not broad proof

# %% [markdown]
# ## Acceptance
#
# 1. PFAS Tyler-literal output exists with canonical files.
# 2. PFAS frozen manifest hashes verify.
# 3. PFAS frozen eval runs successfully.
# 4. Docs record the combined UBI+PFAS result with explicit limits.
