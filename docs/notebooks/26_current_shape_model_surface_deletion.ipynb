# %% [markdown]
# # Current-Shape Model Surface Deletion
#
# **Status:** planned
# **Purpose:** delete the remaining current-shape model/helper surfaces so `main` keeps one canonical Tyler-native runtime vocabulary.

# %% [markdown]
# ## Contract
#
# **Keep:** Tyler Stage 1-6 runtime artifacts and Tyler-native validation / verification / export paths
# **Delete:** `QuestionDecomposition`, `AnalystRun`, `ClaimLedger`, and their helper functions once no live callers remain
# **Preserve old variants by:** commit references in `docs/TYLER_VARIANT_COMMIT_MAP.md`

# %% [markdown]
# ## Ordered Phases
#
# 1. Tyler-native Stage 1 validation
# 2. Delete legacy verification/build/anonymization helpers
# 3. Delete current-shape model classes
# 4. Rewrite active docs and commit map

# %% [markdown]
# ## Acceptance Criteria
#
# - `decompose.py` validates Tyler Stage 1 directly
# - `verify.py` no longer exposes legacy `verify_disputes()`
# - `canonicalize.py` no longer exposes `build_ledger()`
# - `anonymize.py` no longer exposes `scrub_analyst_run()`
# - `models.py` no longer defines `QuestionDecomposition`, `AnalystRun`, or `ClaimLedger`
# - targeted tests pass
# - active docs match the code
