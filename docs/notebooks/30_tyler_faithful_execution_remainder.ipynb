# %% [markdown]
# # Tyler Faithful Execution Remainder
#
# ## Purpose
#
# Define the exact remaining work required to say that `grounded-research`
# faithfully executes Tyler's V1 plan.
#
# ## Current State
#
# - Repo-local runtime cutover is complete.
# - Tyler-native Stage 1-6 artifacts are the live canonical path.
# - Legacy runtime modes are not kept alive in `main`.
# - Remaining work is narrower:
#   - Stage 1/2/5 prompt-literalness closure
#   - frozen-eval expansion beyond one shared case
#   - shared provider/model parity outside this repo
#
# ## Pre-Made Decisions
#
# 1. Tyler-literal remains the default runtime target.
# 2. Archived calibrated legacy remains eval-only.
# 3. Prompt literalness is the default goal; deviations must be justified explicitly.
# 4. Shared provider/model parity stays in `open_web_retrieval`, `llm_client`, and `prompt_eval`.
#
# ## Acceptance
#
# The remainder is closed only if:
#
# - Stage 1/2/5 prompt literalness is closed or justified explicitly.
# - Frozen Tyler-vs-legacy comparison coverage is broader than one case.
# - Remaining non-local Tyler gaps have named shared-infra owners.
