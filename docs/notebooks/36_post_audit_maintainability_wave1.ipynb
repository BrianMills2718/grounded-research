# %% [markdown]
# # Post-Audit Maintainability Wave 1
#
# Status: planned
#
# This notebook is the planning artifact for a tightly limited maintainability wave that exists only to support Tyler remediation.

# %% [markdown]
# ## Inputs
#
# - `docs/TYLER_SPEC_GAP_LEDGER.md`
# - `docs/plans/tyler_gap_remediation_wave1.md`
# - `docs/TYLER_AUDIT_FAILURE_ANALYSIS.md`
# - `src/grounded_research/verify.py`
# - `src/grounded_research/export.py`
# - `engine.py`

# %% [markdown]
# ## Scope Limits
#
# 1. Stage-boundary assertion helpers only.
# 2. Smaller pure-function boundaries only in Stage 5 and Stage 6.
# 3. Ledger ergonomics only if later remediation waves actually need it.
#
# Anything broader is out of scope.

# %% [markdown]
# ## Acceptance Criteria
#
# - later Tyler remediation waves become easier to patch and verify
# - no generic cleanup sprawl is introduced
# - no compatibility paths are reintroduced
