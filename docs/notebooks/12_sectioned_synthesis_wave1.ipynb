# %% [markdown]
# # Sectioned Synthesis Wave 1
#
# Status: planned
#
# This notebook is the review surface for the export-depth gate that decides whether `grounded-research` needs sectioned synthesis in `thorough` mode.

# %% [markdown]
# ## Contract
#
# - Input: saved calibrated `PipelineState` trace from `output/ubi_wave2_report_calibrated/trace.json`
# - Gate: rerender long report with `depth = thorough`
# - Pass: single-call report reaches at least 9,000 words with stable structure
# - Fail: implement sectioned synthesis and rerun the same gate

# %% [markdown]
# ## Pre-Made Decisions
#
# 1. Use the saved calibrated UBI trace as the gate input.
# 2. Treat <9,000 words in thorough mode as a failed gate.
# 3. Reuse the current long-report prompt family; do not invent a second report style.
# 4. Keep the single-call path available for standard mode.
