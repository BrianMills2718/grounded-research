# %% [markdown]
# # Tyler V1 Follow-Through\n\n**Purpose:** Convert the March 26 Tyler V1 review into a stable repo-local boundary note.\n**Status:** completed\n**Execution mode:** docs/plans closure\n\n## Inputs\n- `tyler_response_20260326/` V1 package\n- current `CLAUDE.md` and `docs/PLAN.md`\n- current plan index and shipped benchmark state\n

# %% [markdown]
# ## Decisions\n\n1. Tyler's V1 package remains reference material, not the canonical contract for current repo code.\n2. Tavily/Exa parity belongs in `open_web_retrieval`, not in `grounded-research`.\n3. Gemini structured-output quality concerns belong in `llm_client` / `prompt_eval`.\n4. The proven `research_v3` -> `EvidenceBundle` -> `engine.py --fixture` path is part of the supported system boundary.\n5. Repo-local work is docs/plans closure, not a fresh implementation wave.\n

# %% [markdown]
# ## Acceptance Criteria\n\n- One concise Tyler-to-current-repo mapping note exists\n- `CLAUDE.md` and `AGENTS.md` lock the provider boundary and continuity rule\n- plan surfaces mention this follow-through explicitly\n- remaining Tyler-derived work is categorized as repo-local complete vs shared-infra follow-up\n
