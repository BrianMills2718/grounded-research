# %% [markdown]
# # Thorough Benchmark Preservation Wave 1
#
# Status: completed
#
# This notebook is the review surface for the fresh `thorough` UBI fixture rerun that decides whether `grounded-research` needs another repo-local wave.
#
#
# Outcome: fresh `thorough` rerun completed, but lost to cached Perplexity and to the prior dense-dedup pipeline anchor; no recent-first wave opened.

# %% [markdown]
# ## Contract
#
# - Input fixture: `output/ubi_wave2_prefetch_collection/collected_bundle.json`
# - Paired decomposition: `output/ubi_wave2_prefetch_collection/decomposition.json`
# - Forced depth: `thorough`
# - Outputs: saved report, trace, and fair comparison artifacts
# - Decision: preserve/close vs open recent-first ranking

# %% [markdown]
# ## Pre-Made Decisions
#
# 1. Use the fixture path, not a fresh cold-start retrieval run.
# 2. Compare against cached Perplexity after the run completes.
# 3. Only open recent-first ranking if the completed regression clearly points to stale-source dominance.
# 4. Otherwise close the wave without speculative repo-local code changes.

# %% [markdown]
# ## Result Summary
#
# - Fresh fixture rerun output: `output/ubi_thorough_preservation_wave1/`
# - Fair comparisons: `output/fair_ubi_thorough_preservation_wave1_vs_ubi_perplexity.md` and `output/fair_ubi_thorough_preservation_wave1_vs_ubi_dense_dedup_eval.md`
# - Decision: close the wave with recorded uncertainty; do not open recent-first ranking from this evidence.
