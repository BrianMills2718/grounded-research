# %% [markdown]
# # Stage 5 Internal Protocol Literalization
#
# Goal: remove the remaining current-shape internal protocol types from the live Tyler Stage 5 path.

# %% [markdown]
# ## Canonical Decisions
#
# 1. Live Stage 5 runs on Tyler `DisputeQueueEntry`, `ArbitrationAssessment`, and `VerificationResult`.
# 2. Query accounting stays explicit for `VerificationResult.search_budget`.
# 3. Current-shape Stage 5 projections are deleted rather than hidden behind config.

# %% [markdown]
# ## Acceptance
#
# - `verify.py` no longer uses current-shape `Dispute`, `ArbitrationResult`, `ClaimUpdate`, or `VerificationQueryBatch` in the live path
# - targeted verification/export/phase-boundary tests pass
# - active docs describe Stage 5 as Tyler-native end to end
