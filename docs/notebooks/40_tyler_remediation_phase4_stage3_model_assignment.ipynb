# %% [markdown]
# # Tyler Remediation Phase 4: Stage 3 Model Assignment
#
# Goal: restore Tyler's default B/C frame-model mapping in the shipped runtime config while keeping the cheap testing config explicitly non-literal.
