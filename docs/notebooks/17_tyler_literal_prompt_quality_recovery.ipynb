# %% [markdown]
# # Tyler Literal Prompt Quality Recovery
#
# Status: planned
#
# Purpose:
# - audit active Tyler prompt files against Tyler's prompt spec
# - identify the weakest Tyler-native stages on the tracked UBI fixture
# - repair prompt/runtime quality without reopening already-complete contract migration
# - rerun the same benchmark gate and classify the result honestly

# %% [markdown]
# ## Inputs
#
# - Prompt spec: `tyler_response_20260326/4. V1_PROMPTS (1).md`
# - Current tracked regression: `output/tyler_literal_parity_ubi_reanchor_v5/`
# - Comparison anchors:
#   - `output/ubi_perplexity/perplexity_report.md`
#   - `output/ubi_dense_dedup_eval/report.md`

# %% [markdown]
# ## Gate
#
# Pass if:
# - prompt fidelity is explicitly classified stage by stage
# - the weakest Tyler-native stages are identified with trace evidence
# - a repaired Tyler-native rerun is at least as decision-useful as the dense-dedup anchor, or the remaining loss is precisely attributed
#
# Fail if:
# - prompt literalness is still assumed rather than audited
# - the next rerun still loses and the cause is left ambiguous
