# %% [markdown]
# # Tyler Post-Audit Remediation Wave 2
#
# Purpose: turn the exhaustive Tyler packet audit into the next bounded local implementation wave.

# %% [markdown]
# ## Active Local Rows
#
# 1. `SC-PIPELINESTATE-001`

# %% [markdown]
# ## Execution Order
#
# ### Phase 1: Stage 5/6 Prompt Contract Parity (Completed 2026-04-13)
# - switch Stage 5 to Tyler dict-style claim ledger access
# - switch Stage 6 back to `claim_ledger` + `decision_critical_claim_ids`
# - replace prompt-side `stage_6_user_input` with `user_response_for_dispute`
# - keep compaction on the Tyler-style prompt surface
#
# ### Phase 2: Stage 6 Validation Behavior (Completed 2026-04-13)
# - grounding reject-and-retry once
# - enforce Tyler final-report validation rules in the repair loop
#
# ### Phase 3: Tyler PipelineState Trace Parity (Active)
# - emit Tyler `PipelineState` to `trace.json`
# - preserve partial trace on abort

# %% [markdown]
# ## Verification
#
# - prompt render tests for Stage 5 and Stage 6
# - export/phase-boundary tests for compaction and Stage 6 repair wiring
# - trace-artifact or serializer tests for `PipelineState`
# - `python scripts/sync_plan_status.py --check`
