# %% [markdown]
# # Tyler Remediation Phase 3: Stage 6 Synthesis Context
#
# Goal: patch Stage 6 evidence-context completeness, Tyler-style compaction, and the non-dominant synthesis-model policy in one coordinated wave.

# %% [markdown]
# ## Tyler Priority Order
#
# 1. Original query (always full)
# 2. Decision-critical claims (always full)
# 3. Dispute resolutions (always full)
# 4. Stage 6a user clarifications (always full)
# 5. Evidence highlights for dispute-contributing sources
# 6. Assumptions
# 7. Non-critical claims (compress first)
# 8. Non-dispute evidence (compress to ID + one-line contribution summary)
#
# Anchoring: original query at the start, key disputes/evidence at the end.
