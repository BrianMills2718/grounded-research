# %% [markdown]
# # Tyler Systematic Review Wave 2
#
# This notebook is the planning artifact for the repeatable Tyler review program.
#
# Canonical plan: `docs/plans/tyler_systematic_review_wave2.md`
# Execution tracker: `docs/TYLER_SYSTEMATIC_REVIEW_MATRIX.md`
# Canonical findings ledger: `docs/TYLER_SPEC_GAP_LEDGER.md`

# %% [markdown]
# ## Phases
#
# 1. Freeze review inventory
# 2. Local structure review
# 3. Behavior review
# 4. Docs and status review
# 5. Shared boundary review
# 6. Remediation output

# %% [markdown]
# ## Acceptance Criteria
#
# - every Tyler-relevant lane is represented in the matrix
# - every open ledger row has an explicit owner and next action
# - behavior claims cite runtime evidence
# - docs do not overclaim beyond the ledger
