# %% [markdown]
# # Tyler Audit Governance Wave 1
#
# Status: planned
#
# This notebook is the concrete review artifact for documenting prior Tyler review failure modes, organizing findings, and installing prevention controls.

# %% [markdown]
# ## Inputs
#
# - `docs/TYLER_SPEC_GAP_LEDGER.md`
# - `docs/plans/tyler_spec_gap_audit_wave1.md`
# - `docs/plans/tyler_gap_remediation_wave1.md`
# - `docs/TYLER_EXECUTION_STATUS.md`
# - `docs/PLAN.md`
# - `docs/ROADMAP.md`

# %% [markdown]
# ## Deliverables
#
# 1. `docs/TYLER_AUDIT_FAILURE_ANALYSIS.md`
# 2. `docs/plans/tyler_audit_governance_wave1.md`
# 3. authority-doc references updated to point at the governance layer

# %% [markdown]
# ## Acceptance Criteria
#
# - prior review failure modes are documented with operational root-cause categories
# - new Tyler findings have one intake path from clause to ledger to remediation wave
# - parity or closure claims are explicitly gated on ledger-backed evidence
# - current authority docs reference the governance layer rather than competing with it
