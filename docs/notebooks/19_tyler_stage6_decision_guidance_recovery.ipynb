# %% [markdown]
# # Tyler Stage 6 Decision-Guidance Recovery\n\n- Trigger: `output/tyler_literal_parity_ubi_reanchor_v7_retry1/` beats Perplexity but still loses to the dense-dedup anchor on decision usefulness.\n- Concrete failure mode: rendered report has an empty `Decision-Relevant Tradeoffs` section.\n- Decision: strengthen Stage 6 prompt pressure and add a repair loop for underfilled synthesis fields before changing any broader architecture.\n\n## Acceptance Gate\n\n1. rerun completes with 0 grounding warnings\n2. Stage 6 returns at least one decision tradeoff\n3. preserved alternatives remain non-empty when viable alternatives survive\n4. rerun is no worse than v7 on Stage 4 claim count and cited-claim count\n5. compare against dense-dedup anchor again\n
