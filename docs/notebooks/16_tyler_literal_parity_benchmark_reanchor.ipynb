# %% [markdown]
# # Tyler Literal Parity Benchmark Re-Anchor
#
# Status: in progress
#
# Purpose: verify that the fully Tyler-native runtime survives a real trace and then re-anchor the benchmark surface on that path.

# %% [markdown]
# ## Gates
#
# 1. Smoke: `session_storage_bundle.json` produces a `trace.json` with Tyler Stage 1-6 artifacts
# 2. Benchmark: rerun the tracked benchmark on the Tyler-native runtime
# 3. Outcome: classify the result as preserved, improved, or regressed usefulness

# %% [markdown]
# ## Boundary
#
# - Local schema/prompt wiring is already migrated
# - Provider stalls or search-provider parity remain shared-infra issues unless a local code-level failure is found
