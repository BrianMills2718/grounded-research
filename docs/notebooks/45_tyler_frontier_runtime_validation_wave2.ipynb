# %% [markdown]
# # Tyler Frontier Runtime Validation Wave 2
#
# Goal: determine whether the Stage 3 Claude Opus citation-floor failure is reproducible, intermittent, or isolated.

# %% [markdown]
# ## Runs
#
# - Repeat fixture: `output/full_run/collected_bundle.json`
# - Breadth fixture: `output/what_are_palantir_technologies'_major_us/collected_bundle.json`
# - Evidence per run: `trace.json`, `summary.md`, `llm_observability.db`

# %% [markdown]
# ## Classification
#
# - Reproducible defect: Claude Opus fails the Stage 3 citation floor again
# - Intermittent defect: mixed pass/fail across the two additional runs
# - Cleared on repeat: both additional runs pass cleanly
