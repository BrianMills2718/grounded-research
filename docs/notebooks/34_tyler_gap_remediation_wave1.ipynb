# %% [markdown]
# # Tyler Gap Remediation Wave 1
#
# Status: planned
#
# This notebook is the concrete review artifact for turning the verified Tyler gap ledger into ordered remediation waves.

# %% [markdown]
# ## Inputs
#
# - `docs/TYLER_SPEC_GAP_LEDGER.md`
# - `docs/TYLER_EXECUTION_STATUS.md`
# - `docs/plans/tyler_spec_gap_audit_wave1.md`

# %% [markdown]
# ## Ordered Phases
#
# 1. Stage 6a/Stage 5 orchestration corrections
# 2. Stage 4 extraction-order correction
# 3. Stage 6 synthesis-context corrections
# 4. Stage 3 model assignment correction
# 5. Stage 1/2 retrieval and scoring corrections

# %% [markdown]
# ## Acceptance Shape
#
# Every child wave needs:
#
# - exact ledger rows it closes
# - tests and phase-boundary verification
# - doc updates when row status changes
