# %% [markdown]
# # Tyler Remediation Phase 1: Stage 6a / Stage 5 Orchestration
#
# Status: planned
#
# This notebook is the concrete planning artifact for the first local Tyler remediation child wave.

# %% [markdown]
# ## Target Rows
#
# - `S6A-STEERING-001`
# - `S5-ROUND-CAP-001`
# - `S5-ORDER-RANDOMIZATION-001`

# %% [markdown]
# ## Planned Changes
#
# 1. Move Stage 6a to after Stage 5 when Stage 5 runs.
# 2. Filter steering disputes from the updated queue using Tyler's routed dispute statuses.
# 3. Clamp Stage 5 to a hard max of 2 rounds.
# 4. Randomize analyst-position order before Stage 5 arbitration prompt rendering.

# %% [markdown]
# ## Acceptance Criteria
#
# - the live pipeline no longer skips Tyler-routed steering disputes
# - Stage 5 cannot exceed 2 rounds
# - Stage 5 prompt input order is no longer fixed
# - behavior is proven with tests, not prose alone
