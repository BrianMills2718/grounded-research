# %% [markdown]
# # Legacy Export Surface Deletion
#
# Status: In Progress
#
# Goal: remove compatibility-only export/report surfaces so the repo has one canonical Tyler-native output contract.

# %% [markdown]
# ## Inputs and Outputs
#
# Canonical outputs retained:
# - `PipelineState.tyler_stage_6_result`
# - `PipelineState.tyler_handoff`
# - `report.md`, `summary.md`, `handoff.json`, `trace.json` from Tyler Stage 5/6
#
# Compatibility surfaces to delete from live runtime:
# - `PipelineState.claim_ledger`
# - `FinalReport` generation/rendering helpers in `export.py`
# - legacy handoff fallback in `write_outputs()`

# %% [markdown]
# ## Ordered Phases
#
# 1. Remove stored compatibility export state (`claim_ledger`) from `PipelineState`.
# 2. Delete compatibility export helpers in `export.py`.
# 3. Delete compatibility-only tests and keep Tyler-native coverage.
# 4. Rewrite active docs and update archived variant references.

# %% [markdown]
# ## Acceptance
#
# - No active runtime path writes or reads legacy export surfaces.
# - Active docs describe one canonical Tyler-native export contract.
# - Targeted export/verify/prompt/boundary tests pass after deletions.
