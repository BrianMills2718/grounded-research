# %% [markdown]
# # Remaining Work and Runtime Reliability
#
# ## Purpose
#
# Freeze the remaining implementation surface after Wave 1 and early Wave 2 work so the repo can continue autonomously without drifting between docs, chat, and benchmark artifacts.

# %% [markdown]
# ## Current State
#
# - Core end-to-end pipeline exists.
# - Wave 1 reasoning-quality alignment is complete.
# - Wave 2 quality work is partially complete.
# - The active blocker is runtime reliability on long benchmark runs, not a missing major stage.

# %% [markdown]
# ## Remaining Work Buckets
#
# 1. Wave 2 runtime reliability
#    - run-local observability DB
#    - explicit finite request timeouts
#    - benchmark-safe engine runtime policy
#
# 2. Wave 2 benchmark closure
#    - rerun UBI after reliability fixes
#    - verify dedup/canonicalization remains the true next quality bottleneck
#
# 3. Documentation authority reconciliation
#    - align PLAN / ROADMAP / plans index / CLAUDE

# %% [markdown]
# ## Acceptance Gates
#
# - Long benchmark runs finish without shared-DB lock failures.
# - Long structured calls use finite config-driven request timeouts.
# - The UBI gate completes end-to-end on the improved Wave 2 method.
# - Active docs agree on what is done, active, deferred, and next.
