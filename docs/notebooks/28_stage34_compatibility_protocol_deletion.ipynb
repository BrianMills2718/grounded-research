# %% [markdown]
# # Stage 3/4 Compatibility Protocol Deletion
#
# Goal: remove the dead current-shape Stage 3/4 semantic utility path from `main`.

# %% [markdown]
# ## Canonical Decisions
#
# 1. Tyler `ClaimExtractionResult` is the only shipped Stage 4 contract.
# 2. `deduplicate_claims()` and `detect_disputes()` are deleted rather than retained as compatibility utilities.
# 3. Historical comparison behavior is preserved by commits and benchmark artifacts, not by keeping a second Stage 4 path in runtime code.

# %% [markdown]
# ## Acceptance
#
# - `canonicalize.py` no longer exports the deleted Stage 3/4 compatibility helpers
# - `models.py` no longer defines the dead current-shape Stage 3/4 semantic models and routing table
# - Tyler Stage 4 tests still pass
