# %% [markdown]
# # Tyler Prompt Literalness Wave 1
#
# ## Purpose
#
# Close the remaining repo-local prompt/orchestrator fidelity gap against
# Tyler's V1 prompt package.
#
# ## Target Surfaces
#
# - Stage 1: `prompts/tyler_v1_decompose.yaml`
# - Stage 2: `prompts/tyler_v1_query_diversification.yaml`
# - Stage 2: `prompts/tyler_v1_extract_findings.yaml`
# - Stage 5: neutral verification query generation in `verify.py` and the
#   local verification-query prompt/template surface
#
# ## Pre-Made Decisions
#
# 1. Tyler's source markdown is the contract for this wave.
# 2. Stage 5 query generation remains orchestrator logic, not a model call.
# 3. The wave closes repo-local prompt literalness only; provider/model parity
#    remains shared-infra work.
#
# ## Acceptance
#
# - Each targeted surface gets a line-by-line audit result.
# - Every local divergence is either patched or justified explicitly.
# - Stage 5 query generation emits Tyler's neutral/supporting/authoritative
#   query roles and dated-search behavior when applicable.
