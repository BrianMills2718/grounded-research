# %% [markdown]
# # Tyler Literal Default Eval Wave 1
#
# Status: In progress
#
# This notebook is the review surface for the first shared-eval comparison between the canonical Tyler-literal runtime and the archived calibrated legacy anchor.

# %% [markdown]
# ## Contract
#
# Inputs:
# - frozen manifest pointing at saved grounded-research artifacts
# - Tyler-literal `report.md`
# - calibrated-legacy `report.md`
#
# Execution:
# - `prompt_eval.evaluate_precomputed_variants()` over precomputed outputs
# - quality rubric derived from the existing fair-comparison dimensions
# - repeated judge scoring to estimate judge noise on the single shared case
#
# Outputs:
# - saved EvalResult JSON
# - Markdown summary
# - docs recording the default-policy decision and remaining uncertainties

# %% [markdown]
# ## Success Criteria
#
# 1. manifest is reproducible and hashed
# 2. harness runs end to end from saved artifacts
# 3. result is recorded in canonical docs
# 4. repo keeps one canonical Tyler runtime path

# %% [markdown]
# ## Known Limits
#
# - Wave 1 compares one shared UBI case only.
# - The result is directional, not a final ecosystem-wide proof.
# - Shared provider/model parity remains outside grounded-research and belongs in shared infrastructure.
