# %% [markdown]
# # Tyler Literal Parity Stage 1-3 Native Migration
#
# Status: in progress
#
# Purpose: finish the remaining literal-parity runtime migration by making Stage 1, Stage 2, and Stage 3 native Tyler artifacts instead of adapter-fed inputs.

# %% [markdown]
# ## Contracts
#
# - Stage 1 live output: `DecompositionResult`
# - Stage 2 live output: `EvidencePackage`
# - Stage 3 live output: `AnalysisObject[]`
# - Compatibility projections remain explicit:
#   - `QuestionDecomposition`
#   - `EvidenceBundle`
#   - `AnalystRun[]`
# - Stage 4-6 must consume persisted Tyler Stage 1-3 artifacts when present.

# %% [markdown]
# ## Slice Order
#
# 1. Persistence surfaces in `PipelineState`
# 2. Stage 1 Tyler-native decomposition with projected validation surface
# 3. Stage 2 Tyler-native evidence package using Tyler query diversification and finding extraction prompts
# 4. Stage 3 Tyler-native analyst outputs using Tyler analyst prompts
# 5. Downstream re-anchor so Stage 4-6 prefer persisted Tyler Stage 1-3 artifacts
# 6. Full Tyler parity verification suite and one live smoke/fixture trace gate

# %% [markdown]
# ## Acceptance
#
# - `trace.json` contains Tyler Stage 1-6 artifacts for a current run
# - Stage 1-3 prompt surfaces are Tyler-native in the live runtime
# - Compatibility surfaces remain projections only
# - Shared-infra gaps stay explicitly out of scope for this repo
