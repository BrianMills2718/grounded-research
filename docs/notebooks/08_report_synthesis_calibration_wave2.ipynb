# %% [markdown]
# # Wave 2 Report Synthesis Calibration Planning
#
# ## Problem
#
# After the coverage-breadth slice, the improved UBI rerun produced 38 canonical claims and a broader report, but the fair judge still preferred cached Perplexity. The remaining loss appears to be in report synthesis: contradiction handling, cross-case comparative structure, and symbolic placeholder artifacts.
#
# ## Decisions
#
# 1. Fix the report layer next, not retrieval or analyst breadth again.
# 2. Add one structured-report repair pass when grounding validation fails.
# 3. Add one long-report repair pass only for mechanically detectable synthesis defects, starting with placeholder tokens.
# 4. Strengthen prompts to require contradiction reconciliation and explicit cross-case comparison.
#
# ## Acceptance Gate
#
# - No grounding warnings on the improved UBI gate.
# - No symbolic placeholders such as `X-Y%`.
# - Fair comparison improves, or the next remaining bottleneck becomes narrower and explicit.
