# %% [markdown]
# # Tyler Remediation Phase 7: Stage 2 Exa Retrieval Instruction
#
# ## Goal
#
# Use the newly landed shared `retrieval_instruction` field for Stage 2 Exa semantic queries.
#
# ## Success Criteria
#
# 1. Stage 2 Exa query plans can carry `retrieval_instruction`.
# 2. `search_web_exa()` forwards it into shared `SearchQuery`.
# 3. Local tests prove the instruction is passed through.
