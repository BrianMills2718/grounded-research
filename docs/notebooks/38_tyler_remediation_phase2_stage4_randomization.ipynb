# %% [markdown]
# # Tyler Remediation Phase 2: Stage 4 Randomization
#
# Goal: patch `S4-ORDER-RANDOMIZATION-001` so Stage 4 randomizes analyst presentation order before each claim-extraction call, including retries.

# %% [markdown]
# ## Contracts
#
# - Input: canonical Tyler Stage 3 `AnalysisObject[]`
# - Output: same objects, reordered only for prompt presentation
# - Invariants: no mutation of caller-owned list, alias/content preserved, retry calls re-render from a fresh randomized order
