# %% [markdown]
# # Tyler Literal Parity Refactor
#
# Status: in progress
#
# Purpose: convert Tyler's `V1_SCHEMAS` and `V1_PROMPTS` package from reference material into the literal runtime contract for repo-local surfaces.

# %% [markdown]
# ## Contract
#
# - Input spec: `tyler_response_20260326/3. V1_SCHEMAS (1).md`
# - Input prompts: `tyler_response_20260326/4. V1_PROMPTS (1).md`
# - Audit: `docs/TYLER_LITERAL_PARITY_AUDIT.md`
# - Plan: `docs/plans/tyler_literal_parity_refactor.md`
# - Output: Tyler-native schema classes in code first, then staged runtime migration.

# %% [markdown]
# ## Pre-Made Decisions
#
# 1. This is a major refactor, not a prompt tweak.
# 2. Stage 4 and Stage 6 are explicit contract migrations, not adapter cleanups.
# 3. Shared-infra dependencies remain shared; repo-local literal parity stops at that boundary.
# 4. Phase 0 is contract codification in code before runtime rewiring.

# %% [markdown]
# ## Acceptance
#
# - Tyler enum values exist literally in code.
# - Tyler model classes parse minimal valid fixtures.
# - Subsequent runtime waves target those exact classes instead of ambiguous prose.
