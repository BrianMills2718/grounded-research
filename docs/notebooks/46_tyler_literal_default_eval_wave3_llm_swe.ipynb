# %% [markdown]
# # Tyler Literal Default Eval Wave 3: LLM SWE
#
# ## Goal
#
# Add one non-policy/non-public-health frozen Tyler-vs-legacy case using the saved `llm_swe_v3` artifact.
#
# ## Inputs
#
# - archived calibrated legacy anchor: `output/llm_swe_v3/`
# - saved fixture: `output/llm_swe_v3/collected_bundle.json`
# - current Tyler-literal runtime on `main`
#
# ## Outputs
#
# - `output/tyler_literal_llm_swe_eval_wave3/`
# - `config/eval_manifests/tyler_literal_default_eval_wave3_llm_swe.json`
# - `output/tyler_literal_default_eval_wave3_llm_swe/result.json`
# - `output/tyler_literal_default_eval_wave3_llm_swe/summary.md`
#
# ## Acceptance
#
# - Tyler-literal technical counterpart generated from the saved fixture
# - frozen pair scored through the existing prompt-eval harness
# - status docs updated to a truthful three-case conclusion
