# %% [markdown]
# # Stage 4/5 Projection Deletion
#
# ## Purpose
#
# Remove the remaining live `ClaimLedger` compatibility projections from the Tyler-native runtime path.
#
# ## Canonical Decisions
#
# 1. `canonicalize_tyler_v1()` should return only Tyler Stage 4.
# 2. Stage 5 should expose only Tyler `VerificationResult` in the live runtime path.
# 3. Unused `ClaimLedger` projection helpers are deleted, not hidden behind config.
#
# ## Ordered Phases
#
# ### Phase 1
# - remove Stage 4 compatibility return
# - update engine and canonicalize tests
#
# ### Phase 2
# - delete dead Stage 5 ledger adapter and trim tests
#
# ### Phase 3
# - rewrite active docs and commit map
#
# ## Acceptance
#
# - canonicalize returns only Tyler Stage 4
# - engine no longer unpacks ignored compatibility data
# - Stage 5 current-ledger adapter deleted if unused
# - targeted tests pass
# - active docs describe remaining adapter debt precisely
