# %% [markdown]
# # Isolated Compatibility Surface Deletion
#
# **Status:** planned
# **Purpose:** delete non-live compatibility APIs so `main` keeps one canonical Tyler-native runtime vocabulary.

# %% [markdown]
# ## Contract
#
# **Keep:** Tyler Stage 1-6 runtime entrypoints and artifacts
# **Delete:** current-shape runtime entrypoints (`decompose_with_validation`, legacy `run_analyst`/`run_analysts`, current-shape claim-extraction path)
# **Preserve old variants by:** commit references in `docs/TYLER_VARIANT_COMMIT_MAP.md`

# %% [markdown]
# ## Ordered Phases
#
# 1. Delete current-shape Stage 1 runtime entrypoints
# 2. Delete legacy Stage 3 execution path
# 3. Delete current-shape Stage 3/3a compatibility helpers
# 4. Rewrite active docs and commit map
