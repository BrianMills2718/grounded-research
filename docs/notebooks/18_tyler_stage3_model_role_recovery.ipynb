# %% [markdown]
# # Tyler Stage 3 Model-Role Recovery\n\n- Goal: recover Tyler-native Stage 3 quality on the tracked UBI fixture without reopening already-migrated Tyler contracts.\n- Trigger: `output/tyler_literal_parity_ubi_reanchor_v6/` still loses to both anchors and exposed DeepSeek structured-output instability plus uneven analyst density.\n- Decision: use the closest locally available Tyler role mapping and remove DeepSeek from the primary analyst path.\n\n## Closest-Available Stage 3 Mapping\n\n- Analyst A / step-back abstraction -> `openrouter/openai/gpt-5.4-mini`\n- Analyst B / structured decomposition -> `gemini/gemini-2.5-flash`\n- Analyst C / verification-first -> `openrouter/openai/gpt-5.4-nano`\n\n## Acceptance Gate\n\n1. targeted Stage 3/runtime tests pass\n2. rerun completes with no export grounding warnings\n3. no analyst returns fewer than 5 claims\n4. rerun is no worse than v6 on Stage 4 claim count and final cited-claim count\n\n## Explicit Concern\n\nExact Tyler Stage 3 model-role parity is still blocked locally by shared model availability: Claude Opus 4.6 is not present in the current shared registry, so this wave closes only the repo-local closest-available mapping.
